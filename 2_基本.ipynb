# %%
import pandas as pd

filename = 'all.csv'
df = pd.read_csv(filename, converters={'code': str})
print('Done', len(df))
# Out:
# Done 5361

# %%
import akshare as ak

#debug
'''
import pandas as pd
data = {
    'code': ['600737'],
    'name': ['中粮糖业']
}
df = pd.DataFrame(data)
filename = 'temp.csv'
'''
df['行业'] = ''
df['上市时间'] = ''
#df['总市值'] = ''
for idx, row in df.iterrows():
    #progress dot
    print('.', end = '')
    if (idx + 1) % 80 == 0: print('')
    
    code = row['code']
    df_info = ak.stock_individual_info_em(symbol = code)
    #debug
    #print(df_info)
    df.at[idx, '行业'] = df_info.loc[df_info['item'] == '行业', 'value'].values[-1]  
    df.at[idx, '上市时间'] = df_info.loc[df_info['item'] == '上市时间', 'value'].values[-1]
    #df.at[idx, '总市值'] = round(df_info.loc[df_info['item'] == '总市值', 'value'].values[-1] / 100000000)

print('\r\nDone', len(df))
df.to_csv(filename, index = False)
df.head(3)
# Out:
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ................................................................................
# ...
